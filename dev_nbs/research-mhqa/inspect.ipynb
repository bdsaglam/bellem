# %%
import json
from pathlib import Path
import pandas as pd

# %%
DATA_DIR = Path("../../data/generated/research-mhqa-evaluation/")

# %%
df = pd.read_json(DATA_DIR / "reports/results.jsonl", lines=True)
df.head()
# Out:
#                     id                                         paragraphs  \
# 0  2hop__131818_161450  [{'idx': 0, 'title': 'Maria Carrillo High Scho...
# 1   2hop__444265_82341  [{'idx': 0, 'title': 'Ocala, Florida', 'paragr...
# 2  2hop__711946_269414  [{'idx': 0, 'title': 'Wild Thing (Tone Lōc son...
# 3  2hop__311931_417706  [{'idx': 0, 'title': 'The Main Attraction (alb...
# 4  2hop__809785_606637  [{'idx': 0, 'title': 'The Main Attraction (alb...
#
#                                             question  \
# 0            Where is the Voshmgir District located?
# 1  In what part of Florida is Tom Denney's birthp...
# 2  What record label is the performer who release...
# 3  What record label does the performer of Emotio...
# 4  What record label does the performer of Advent...
#
#                               question_decomposition               answer  \
# 0  [{'id': 131818, 'question': 'Which state is Vo...    Golestan Province
# 1  [{'id': 444265, 'question': 'Tom Denney >> pla...     Northern Florida
# 2  [{'id': 711946, 'question': 'All Your Faded Th...   Cold Crush Records
# 3  [{'id': 311931, 'question': 'Emotional Rain >>...          A&M Records
# 4  [{'id': 809785, 'question': 'Adventures in You...  Secret City Records
#
#                                       answer_aliases  answerable  \
# 0  [Caspian Sea, in the north-east of the country...        True
# 1            [in Northern Florida, Northern Florida]        True
# 2                                  [Kill Rock Stars]        True
# 3                             [Attic, Attic Records]        True
# 4                              [Secret City Records]        True
#
#                                              answers  \
# 0  [Caspian Sea, in the north-east of the country...
# 1            [in Northern Florida, Northern Florida]
# 2                                  [Kill Rock Stars]
# 3                             [Attic, Attic Records]
# 4                              [Secret City Records]
#
#                                                 hops     predicted_answer  \
# 0  [{'question': 'Where is the Voshmgir District ...    Golestan Province
# 1  [{'question': 'In what part of Florida is Tom ...     Northern Florida
# 2  [{'question': 'What record label is the perfor...   Cold Crush Records
# 3  [{'question': 'What record label does the perf...          A&M Records
# 4  [{'question': 'What record label does the perf...  Secret City Records
#
#                                    reference_answers  exact_match   f1  \
# 0  [Caspian Sea, in the north-east of the country...            0  0.0
# 1            [in Northern Florida, Northern Florida]            1  1.0
# 2                                  [Kill Rock Stars]            0  0.0
# 3                             [Attic, Attic Records]            0  0.5
# 4                              [Secret City Records]            1  1.0
#
#    fuzzy_match
# 0            0
# 1            1
# 2            0
# 3            1
# 4            1
