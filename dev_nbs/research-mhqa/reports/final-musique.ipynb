# %%
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

# %%
manual_records = [
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "standard",
        "optimization": "manual/2-shot",
        "exact_match": 0.595918,
        "f1": 0.711330,
    },
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "cot",
        "optimization": "manual/0-shot",
        "exact_match": 0.537443,
        "f1": 0.658576,
    },
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "cte",
        "optimization": "manual/2-shot",
        "exact_match": 0.648738,
        "f1": 0.751376,
    },
]

dspy_records = [
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "standard",
        "optimization": "auto/bfsrs-medium",
        "exact_match": 0.6326023996690112,
        "f1": 0.7421867020999712,

    },
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "cot",
        "optimization": "auto/bfsrs-medium",
        "exact_match": 0.6168804302854779,
        "f1": 0.7369758498771094,
    },
    {
        "model": "llama-3-70b-tgi",
        "temperature": 0.1,
        "dataset": "musique/validation",
        "technique": "cte",
        "optimization": "auto/bfs-medium",
        "exact_match": 0.6181216383947041,
        "f1": 0.7353884126505528,
    },
]

df = pd.DataFrame(manual_records + dspy_records)
df
# Out:
#              model  temperature             dataset technique  \
# 0  llama-3-70b-tgi          0.1  musique/validation  standard
# 1  llama-3-70b-tgi          0.1  musique/validation       cot
# 2  llama-3-70b-tgi          0.1  musique/validation       cte
# 3  llama-3-70b-tgi          0.1  musique/validation  standard
# 4  llama-3-70b-tgi          0.1  musique/validation       cot
# 5  llama-3-70b-tgi          0.1  musique/validation       cte
#
#         optimization  exact_match        f1
# 0      manual/2-shot     0.595918  0.711330
# 1      manual/0-shot     0.537443  0.658576
# 2      manual/2-shot     0.648738  0.751376
# 3  auto/bfsrs-medium     0.632602  0.742187
# 4  auto/bfsrs-medium     0.616880  0.736976
# 5    auto/bfs-medium     0.618122  0.735388

# %%
df.drop(columns=["model", "temperature", "dataset"], inplace=True)
df
# Out:
#   technique       optimization  exact_match        f1
# 0  standard      manual/2-shot     0.595918  0.711330
# 1       cot      manual/0-shot     0.537443  0.658576
# 2       cte      manual/2-shot     0.648738  0.751376
# 3  standard  auto/bfsrs-medium     0.632602  0.742187
# 4       cot  auto/bfsrs-medium     0.616880  0.736976
# 5       cte    auto/bfs-medium     0.618122  0.735388

# %%
_df = df.set_index(["technique"])

# Define the desired order for the second index
technique_order = ["standard", "cot", "cte"]

# Reindex the DataFrame to apply the desired order to the second index
_df = _df.loc[technique_order].reset_index()

# Display the styled DataFrame
styled_df = _df.style.highlight_max(subset=["f1"], props="font-weight: bold;").format(precision=3)
display(styled_df)
# Out:
# <style type="text/css">
# #T_3f0d6_row4_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_3f0d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f0d6_level0_col0" class="col_heading level0 col0" >technique</th>
#       <th id="T_3f0d6_level0_col1" class="col_heading level0 col1" >optimization</th>
#       <th id="T_3f0d6_level0_col2" class="col_heading level0 col2" >exact_match</th>
#       <th id="T_3f0d6_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f0d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f0d6_row0_col0" class="data row0 col0" >standard</td>
#       <td id="T_3f0d6_row0_col1" class="data row0 col1" >manual/2-shot</td>
#       <td id="T_3f0d6_row0_col2" class="data row0 col2" >0.596</td>
#       <td id="T_3f0d6_row0_col3" class="data row0 col3" >0.711</td>
#     </tr>
#     <tr>
#       <th id="T_3f0d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f0d6_row1_col0" class="data row1 col0" >standard</td>
#       <td id="T_3f0d6_row1_col1" class="data row1 col1" >auto/bfsrs-medium</td>
#       <td id="T_3f0d6_row1_col2" class="data row1 col2" >0.633</td>
#       <td id="T_3f0d6_row1_col3" class="data row1 col3" >0.742</td>
#     </tr>
#     <tr>
#       <th id="T_3f0d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f0d6_row2_col0" class="data row2 col0" >cot</td>
#       <td id="T_3f0d6_row2_col1" class="data row2 col1" >manual/0-shot</td>
#       <td id="T_3f0d6_row2_col2" class="data row2 col2" >0.537</td>
#       <td id="T_3f0d6_row2_col3" class="data row2 col3" >0.659</td>
#     </tr>
#     <tr>
#       <th id="T_3f0d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f0d6_row3_col0" class="data row3 col0" >cot</td>
#       <td id="T_3f0d6_row3_col1" class="data row3 col1" >auto/bfsrs-medium</td>
#       <td id="T_3f0d6_row3_col2" class="data row3 col2" >0.617</td>
#       <td id="T_3f0d6_row3_col3" class="data row3 col3" >0.737</td>
#     </tr>
#     <tr>
#       <th id="T_3f0d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3f0d6_row4_col0" class="data row4 col0" >cte</td>
#       <td id="T_3f0d6_row4_col1" class="data row4 col1" >manual/2-shot</td>
#       <td id="T_3f0d6_row4_col2" class="data row4 col2" >0.649</td>
#       <td id="T_3f0d6_row4_col3" class="data row4 col3" >0.751</td>
#     </tr>
#     <tr>
#       <th id="T_3f0d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3f0d6_row5_col0" class="data row5 col0" >cte</td>
#       <td id="T_3f0d6_row5_col1" class="data row5 col1" >auto/bfs-medium</td>
#       <td id="T_3f0d6_row5_col2" class="data row5 col2" >0.618</td>
#       <td id="T_3f0d6_row5_col3" class="data row5 col3" >0.735</td>
#     </tr>
#   </tbody>
# </table>
