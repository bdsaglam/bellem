# %% [markdown]
# The experiments were run with the following command:
# ```sh
# dvc exp run --queue \
#     -S dataset.path='bdsaglam/musique-2hop' \
#     -S qa.model='llama-3-70b-tgi,gpt-4o,gpt-3.5-turbo' \
#     -S qa.prompt='standard,cot-zs,cot-fs,cte' \
#     -S run='1'
# ```

# %%
import json
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from bellem.dvc.experiment import load_experiments

experiments = load_experiments('ablation-llm-2hop.json')
print(f"{len(experiments)} experiments")
experiments[0]
# Out:
# 13 experiments
# {'commit': 'workspace',
#  'id': 'workspace',
#  'name': None,
#  'params': {'dataset': {'path': 'bdsaglam/musique-2hop',
#    'name': 'answerable',
#    'split': 'validation'},
#   'qa': {'prompt': 'standard', 'model': 'llama-3-70b-tgi', 'temperature': 0.1},
#   'run': 1},
#  'metrics': {'exact_match': 0.5, 'f1': 0.6599999999999999, 'fuzzy_match': 0.7}}

# %%
df = (
    pd.json_normalize(experiments)
    .sort_values(["params.qa.model", "params.qa.prompt", "params.qa.temperature", "params.run"])
    .drop(columns=["commit", "id"])
)

param_cols = [col for col in df.columns if col.startswith("params.")]
metric_cols = [col for col in df.columns if col.startswith("metrics.")]
df.drop_duplicates(subset=param_cols, inplace=True)

mask = df["params.dataset.path"] == "bdsaglam/musique-2hop"
df = df.loc[mask].copy()
df
# Out:
#           name    params.dataset.path params.dataset.name  \
# 2   hulky-dent  bdsaglam/musique-2hop          answerable
# 4   ruddy-harl  bdsaglam/musique-2hop          answerable
# 6   winey-belt  bdsaglam/musique-2hop          answerable
# 7   lated-yegg  bdsaglam/musique-2hop          answerable
# 1   nubby-hake  bdsaglam/musique-2hop          answerable
# 3   apeak-salt  bdsaglam/musique-2hop          answerable
# 5   cross-typo  bdsaglam/musique-2hop          answerable
# 8   dumpy-tams  bdsaglam/musique-2hop          answerable
# 9   focal-hose  bdsaglam/musique-2hop          answerable
# 10  split-ludo  bdsaglam/musique-2hop          answerable
# 12  roman-divs  bdsaglam/musique-2hop          answerable
# 0         None  bdsaglam/musique-2hop          answerable
#
#    params.dataset.split params.qa.prompt  params.qa.model  \
# 2            validation           cot-fs    gpt-3.5-turbo
# 4            validation           cot-zs    gpt-3.5-turbo
# 6            validation              cte    gpt-3.5-turbo
# 7            validation         standard    gpt-3.5-turbo
# 1            validation           cot-fs           gpt-4o
# 3            validation           cot-zs           gpt-4o
# 5            validation              cte           gpt-4o
# 8            validation         standard           gpt-4o
# 9            validation           cot-fs  llama-3-70b-tgi
# 10           validation           cot-zs  llama-3-70b-tgi
# 12           validation              cte  llama-3-70b-tgi
# 0            validation         standard  llama-3-70b-tgi
#
#     params.qa.temperature  params.run  metrics.exact_match  metrics.f1  \
# 2                     0.1           1             0.551917    0.692852
# 4                     0.1           1             0.536741    0.670746
# 6                     0.1           1             0.575080    0.707971
# 7                     0.1           1             0.405751    0.487911
# 1                     0.1           1             0.607827    0.737075
# 3                     0.1           1             0.561502    0.699257
# 5                     0.1           1             0.655751    0.782515
# 8                     0.1           1             0.595847    0.739225
# 9                     0.1           1             0.498403    0.582141
# 10                    0.1           1             0.495208    0.583063
# 12                    0.1           1             0.652556    0.753282
# 0                     0.1           1             0.500000    0.660000
#
#     metrics.fuzzy_match
# 2              0.629393
# 4              0.607029
# 6              0.654153
# 7              0.456869
# 1              0.686102
# 3              0.644569
# 5              0.735623
# 8              0.682907
# 9              0.546326
# 10             0.543930
# 12             0.707668
# 0              0.700000

# %%
df.drop(
    columns=["name", "params.dataset.path", "params.dataset.name", "params.dataset.split"]
).groupby(["params.qa.model", "params.qa.prompt", "params.qa.temperature"]).aggregate(["mean", "max", "count"]).loc[:, metric_cols]
# Out:
#                                                        metrics.exact_match  \
#                                                                       mean
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                              0.551917
#                 cot-zs           0.1                              0.536741
#                 cte              0.1                              0.575080
#                 standard         0.1                              0.405751
# gpt-4o          cot-fs           0.1                              0.607827
#                 cot-zs           0.1                              0.561502
#                 cte              0.1                              0.655751
#                 standard         0.1                              0.595847
# llama-3-70b-tgi cot-fs           0.1                              0.498403
#                 cot-zs           0.1                              0.495208
#                 cte              0.1                              0.652556
#                 standard         0.1                              0.500000
#
#                                                                         \
#                                                              max count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                    0.551917     1
#                 cot-zs           0.1                    0.536741     1
#                 cte              0.1                    0.575080     1
#                 standard         0.1                    0.405751     1
# gpt-4o          cot-fs           0.1                    0.607827     1
#                 cot-zs           0.1                    0.561502     1
#                 cte              0.1                    0.655751     1
#                 standard         0.1                    0.595847     1
# llama-3-70b-tgi cot-fs           0.1                    0.498403     1
#                 cot-zs           0.1                    0.495208     1
#                 cte              0.1                    0.652556     1
#                 standard         0.1                    0.500000     1
#
#                                                        metrics.f1            \
#                                                              mean       max
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                     0.692852  0.692852
#                 cot-zs           0.1                     0.670746  0.670746
#                 cte              0.1                     0.707971  0.707971
#                 standard         0.1                     0.487911  0.487911
# gpt-4o          cot-fs           0.1                     0.737075  0.737075
#                 cot-zs           0.1                     0.699257  0.699257
#                 cte              0.1                     0.782515  0.782515
#                 standard         0.1                     0.739225  0.739225
# llama-3-70b-tgi cot-fs           0.1                     0.582141  0.582141
#                 cot-zs           0.1                     0.583063  0.583063
#                 cte              0.1                     0.753282  0.753282
#                 standard         0.1                     0.660000  0.660000
#
#                                                               \
#                                                        count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
# gpt-4o          cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
# llama-3-70b-tgi cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
#
#                                                        metrics.fuzzy_match  \
#                                                                       mean
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                              0.629393
#                 cot-zs           0.1                              0.607029
#                 cte              0.1                              0.654153
#                 standard         0.1                              0.456869
# gpt-4o          cot-fs           0.1                              0.686102
#                 cot-zs           0.1                              0.644569
#                 cte              0.1                              0.735623
#                 standard         0.1                              0.682907
# llama-3-70b-tgi cot-fs           0.1                              0.546326
#                 cot-zs           0.1                              0.543930
#                 cte              0.1                              0.707668
#                 standard         0.1                              0.700000
#
#
#                                                              max count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                    0.629393     1
#                 cot-zs           0.1                    0.607029     1
#                 cte              0.1                    0.654153     1
#                 standard         0.1                    0.456869     1
# gpt-4o          cot-fs           0.1                    0.686102     1
#                 cot-zs           0.1                    0.644569     1
#                 cte              0.1                    0.735623     1
#                 standard         0.1                    0.682907     1
# llama-3-70b-tgi cot-fs           0.1                    0.546326     1
#                 cot-zs           0.1                    0.543930     1
#                 cte              0.1                    0.707668     1
#                 standard         0.1                    0.700000     1

# %%
df.groupby(["params.qa.model", "params.qa.prompt", "params.qa.temperature"])[metric_cols].agg(["mean", "max", "count"])
# Out:
#                                                        metrics.exact_match  \
#                                                                       mean
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                              0.551917
#                 cot-zs           0.1                              0.536741
#                 cte              0.1                              0.575080
#                 standard         0.1                              0.405751
# gpt-4o          cot-fs           0.1                              0.607827
#                 cot-zs           0.1                              0.561502
#                 cte              0.1                              0.655751
#                 standard         0.1                              0.595847
# llama-3-70b-tgi cot-fs           0.1                              0.498403
#                 cot-zs           0.1                              0.495208
#                 cte              0.1                              0.652556
#                 standard         0.1                              0.500000
#
#                                                                         \
#                                                              max count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                    0.551917     1
#                 cot-zs           0.1                    0.536741     1
#                 cte              0.1                    0.575080     1
#                 standard         0.1                    0.405751     1
# gpt-4o          cot-fs           0.1                    0.607827     1
#                 cot-zs           0.1                    0.561502     1
#                 cte              0.1                    0.655751     1
#                 standard         0.1                    0.595847     1
# llama-3-70b-tgi cot-fs           0.1                    0.498403     1
#                 cot-zs           0.1                    0.495208     1
#                 cte              0.1                    0.652556     1
#                 standard         0.1                    0.500000     1
#
#                                                        metrics.f1            \
#                                                              mean       max
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                     0.692852  0.692852
#                 cot-zs           0.1                     0.670746  0.670746
#                 cte              0.1                     0.707971  0.707971
#                 standard         0.1                     0.487911  0.487911
# gpt-4o          cot-fs           0.1                     0.737075  0.737075
#                 cot-zs           0.1                     0.699257  0.699257
#                 cte              0.1                     0.782515  0.782515
#                 standard         0.1                     0.739225  0.739225
# llama-3-70b-tgi cot-fs           0.1                     0.582141  0.582141
#                 cot-zs           0.1                     0.583063  0.583063
#                 cte              0.1                     0.753282  0.753282
#                 standard         0.1                     0.660000  0.660000
#
#                                                               \
#                                                        count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
# gpt-4o          cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
# llama-3-70b-tgi cot-fs           0.1                       1
#                 cot-zs           0.1                       1
#                 cte              0.1                       1
#                 standard         0.1                       1
#
#                                                        metrics.fuzzy_match  \
#                                                                       mean
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                              0.629393
#                 cot-zs           0.1                              0.607029
#                 cte              0.1                              0.654153
#                 standard         0.1                              0.456869
# gpt-4o          cot-fs           0.1                              0.686102
#                 cot-zs           0.1                              0.644569
#                 cte              0.1                              0.735623
#                 standard         0.1                              0.682907
# llama-3-70b-tgi cot-fs           0.1                              0.546326
#                 cot-zs           0.1                              0.543930
#                 cte              0.1                              0.707668
#                 standard         0.1                              0.700000
#
#
#                                                              max count
# params.qa.model params.qa.prompt params.qa.temperature
# gpt-3.5-turbo   cot-fs           0.1                    0.629393     1
#                 cot-zs           0.1                    0.607029     1
#                 cte              0.1                    0.654153     1
#                 standard         0.1                    0.456869     1
# gpt-4o          cot-fs           0.1                    0.686102     1
#                 cot-zs           0.1                    0.644569     1
#                 cte              0.1                    0.735623     1
#                 standard         0.1                    0.682907     1
# llama-3-70b-tgi cot-fs           0.1                    0.546326     1
#                 cot-zs           0.1                    0.543930     1
#                 cte              0.1                    0.707668     1
#                 standard         0.1                    0.700000     1

# %%
# Average metrics over repeated runs (params.run)
df_avg = (
    df.groupby(["params.qa.model", "params.qa.prompt", "params.qa.temperature"])[
        ["metrics.exact_match", "metrics.f1", "metrics.fuzzy_match"]
    ]
    .mean()
    .reset_index()
)
df_avg
# Out:
#     params.qa.model params.qa.prompt  params.qa.temperature  \
# 0     gpt-3.5-turbo           cot-fs                    0.1
# 1     gpt-3.5-turbo           cot-zs                    0.1
# 2     gpt-3.5-turbo              cte                    0.1
# 3     gpt-3.5-turbo         standard                    0.1
# 4            gpt-4o           cot-fs                    0.1
# 5            gpt-4o           cot-zs                    0.1
# 6            gpt-4o              cte                    0.1
# 7            gpt-4o         standard                    0.1
# 8   llama-3-70b-tgi           cot-fs                    0.1
# 9   llama-3-70b-tgi           cot-zs                    0.1
# 10  llama-3-70b-tgi              cte                    0.1
# 11  llama-3-70b-tgi         standard                    0.1
#
#     metrics.exact_match  metrics.f1  metrics.fuzzy_match
# 0              0.551917    0.692852             0.629393
# 1              0.536741    0.670746             0.607029
# 2              0.575080    0.707971             0.654153
# 3              0.405751    0.487911             0.456869
# 4              0.607827    0.737075             0.686102
# 5              0.561502    0.699257             0.644569
# 6              0.655751    0.782515             0.735623
# 7              0.595847    0.739225             0.682907
# 8              0.498403    0.582141             0.546326
# 9              0.495208    0.583063             0.543930
# 10             0.652556    0.753282             0.707668
# 11             0.500000    0.660000             0.700000

# %%
prompt_order = ['standard', 'cot-zs', 'cot-fs', 'cte']
df_avg['params.qa.prompt'] = pd.Categorical(df_avg['params.qa.prompt'], categories=prompt_order, ordered=True)
df_avg = df_avg.sort_values('params.qa.prompt')
df_avg
# Out:
#     params.qa.model params.qa.prompt  params.qa.temperature  \
# 3     gpt-3.5-turbo         standard                    0.1
# 7            gpt-4o         standard                    0.1
# 11  llama-3-70b-tgi         standard                    0.1
# 1     gpt-3.5-turbo           cot-zs                    0.1
# 5            gpt-4o           cot-zs                    0.1
# 9   llama-3-70b-tgi           cot-zs                    0.1
# 0     gpt-3.5-turbo           cot-fs                    0.1
# 4            gpt-4o           cot-fs                    0.1
# 8   llama-3-70b-tgi           cot-fs                    0.1
# 2     gpt-3.5-turbo              cte                    0.1
# 6            gpt-4o              cte                    0.1
# 10  llama-3-70b-tgi              cte                    0.1
#
#     metrics.exact_match  metrics.f1  metrics.fuzzy_match
# 3              0.405751    0.487911             0.456869
# 7              0.595847    0.739225             0.682907
# 11             0.500000    0.660000             0.700000
# 1              0.536741    0.670746             0.607029
# 5              0.561502    0.699257             0.644569
# 9              0.495208    0.583063             0.543930
# 0              0.551917    0.692852             0.629393
# 4              0.607827    0.737075             0.686102
# 8              0.498403    0.582141             0.546326
# 2              0.575080    0.707971             0.654153
# 6              0.655751    0.782515             0.735623
# 10             0.652556    0.753282             0.707668

# %%
# Get unique models and prompts
models = df_avg['params.qa.model'].unique()
prompts = df_avg['params.qa.prompt'].unique()

# Set up the figure and axes
fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
fig.suptitle('Comparison of EM and F1 Metrics by Prompt for Different Models')

x = np.arange(len(prompts))
width = 0.35 / len(models)  # Adjust width based on the number of models

# Plot EM and F1 scores for each model
for i, model in enumerate(models):
    model_df = df_avg[df_avg['params.qa.model'] == model]
    ax[0].bar(x + (i - len(models) / 2) * width, model_df['metrics.exact_match'], width, label=model)
    ax[1].bar(x + (i - len(models) / 2) * width, model_df['metrics.f1'], width, label=model)

# Set labels and titles for EM scores plot
ax[0].set_ylabel('Exact Match (EM)')
ax[0].set_title('Exact Match (EM) Score')
ax[0].set_xticks(x)
ax[0].set_xticklabels(prompts)
ax[0].legend(loc='best')

# Set labels and titles for F1 scores plot
ax[1].set_xlabel('Prompt')
ax[1].set_ylabel('F1 Score')
ax[1].set_title('F1 Score')
ax[1].set_xticks(x)
ax[1].set_xticklabels(prompts)
ax[1].legend(loc='best')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
