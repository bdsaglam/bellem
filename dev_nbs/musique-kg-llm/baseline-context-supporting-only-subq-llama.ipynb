# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
import warnings
from pathlib import Path

import pandas as pd

from bellek.text.utils import fuzzy_match
from bellek.utils import set_seed, jprint

set_seed(41)

# %%
ds_df = pd.read_json('../../data/generated/musique-evaluation/dataset.jsonl', orient='records', lines=True)
qd_df = pd.read_json('../../data/generated/musique-evaluation/question-decomposition.jsonl', orient='records', lines=True)
df = pd.merge(ds_df.drop(columns=['question', 'question_decomposition']), qd_df, on='id', suffixes=('', ''))
df.head()
# Out:
#                     id                                         paragraphs  \
# 0  2hop__131818_161450  [{'idx': 0, 'title': 'Maria Carrillo High Scho...
# 1   2hop__444265_82341  [{'idx': 0, 'title': 'Ocala, Florida', 'paragr...
# 2  2hop__711946_269414  [{'idx': 0, 'title': 'Wild Thing (Tone Lōc son...
# 3  2hop__311931_417706  [{'idx': 0, 'title': 'The Main Attraction (alb...
# 4  2hop__809785_606637  [{'idx': 0, 'title': 'The Main Attraction (alb...
#
#                                               answer  \
# 0  in the north-east of the country south of the ...
# 1                                in Northern Florida
# 2                                    Kill Rock Stars
# 3                                      Attic Records
# 4                                Secret City Records
#
#                                       answer_aliases  answerable  \
# 0  [in the north-east of the country south of the...        True
# 1            [Northern Florida, in Northern Florida]        True
# 2                                  [Kill Rock Stars]        True
# 3                             [Attic, Attic Records]        True
# 4                              [Secret City Records]        True
#
#                                             question  \
# 0            Where is the Voshmgir District located?
# 1  In what part of Florida is Tom Denney's birthp...
# 2  What record label is the performer who release...
# 3  What record label does the performer of Emotio...
# 4  What record label does the performer of Advent...
#
#                               question_decomposition
# 0  [{'question': 'Which country is the Voshmgir D...
# 1  [{'question': 'Where is Tom Denney's birthplac...
# 2  [{'question': 'Who is the performer that relea...
# 3  [{'question': 'Who is the performer of Emotion...
# 4  [{'question': 'Who is the performer of Adventu...

# %%
def make_docs(example, only_supporting=False):
    ps = example["paragraphs"]
    for p in ps:
        if only_supporting and not p["is_supporting"]:
            continue
        idx = p["idx"]
        title = p["title"]
        body = p["paragraph_text"]
        is_supporting = p["is_supporting"]
        text = f"# {title}\n{body}"
        yield dict(
            text=text,
            metadata={"parent_id": example["id"], "idx": idx, "is_supporting": is_supporting},
        )

# %%
def present_example(example, predicted_answer):
    text = "\n\n".join([p["paragraph_text"] for p in example['paragraphs']])
    print("="*80)
    print("Question:", example["question"])
    print("Reference Answer:", example['answer'])
    print("Predicted Answer:", predicted_answer)
    print("-"*80)
    print("Paragraphs")
    print(text)

# %%
from magentic import chatprompt, SystemMessage, UserMessage
from pydantic import BaseModel, Field

class Output(BaseModel):
    """Output containing the answers for questions."""
    reasoning: str = Field(description="Multi-hop reasoning for the answer.")
    answer: str


SYSTEM_PROMPT = """You are an expert multi-hop Q&A system that is trusted around the world.
You are given a question and its decomposition to sub-questions. You reach to the answer by answering each sub-question. Always answer the query using the provided context information, and not prior knowledge.
Some rules to follow:
1. Never directly reference the given context in your answer.
2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines.
3. Your answers must be 2-4 words long.

Response Format:
Reasoning: ...
Answer for sub-question 1: ...
Final Answer: ...
"""

USER_PROMPT = """Context information is below.
---------------------
{context_str}
---------------------
Given the context information and not prior knowledge, answer the question.
{query_str}
"""

@chatprompt(
    SystemMessage(SYSTEM_PROMPT),
    UserMessage(USER_PROMPT),
)
def answer_question(context_str: str, query_str: str) -> str: ...

# %%
from magentic import OpenaiChatModel

llm = OpenaiChatModel(
    model="meta-llama/Meta-Llama-3-70B-Instruct",
    temperature=0.0,
    base_url="http://127.0.0.1:8080/v1",
    api_key="anything",
)

# %%
def format_question(example):
    sub_questions = '\n'.join([f"  Sub-question {i+1}: {item['question']}" for i, item in enumerate(example['question_decomposition'])])
    return f"\n{sub_questions}"

# %%
def answer(example):
    documents = list(make_docs(example, only_supporting=False))
    context = "\n\n".join([doc["text"] for doc in documents])
    with llm:
        text = answer_question(context_str=context, query_str=format_question(example))
    lines = text.splitlines()
    answer = None
    for line in lines:
        if line.lower().startswith("final answer"):
            answer = line.split(":")[1].strip()
    example['predicted_answer'] = answer
    example['raw_llm_output'] = text
    return example

# %%
def safe_answer(example):
    try:
        return answer(example)
    except Exception as exc:
        id = example['id']
        print(f"Failed to answer the question {id}\n{exc}")
        example['predicted_answer'] = ''
        example['raw_llm_output'] = ''
        return example

# %%
# from langchain.globals import set_debug
# set_debug(True)

# i = 0
# example = df.iloc[i].to_dict()
# example_ = answer(example)
# print("Question:", example['question'])
# print("Reference answer:", example['answer'])
# print("Predicted answer:", example_['predicted_answer'])

# print("-"*20)
# jprint(example_['raw_llm_output'])

# set_debug(False)

# %%
df = df.apply(safe_answer, axis=1)
# Out:
# Failed to answer the question 2hop__398344_85513
# list index out of range

# %% [markdown]
# ## Evaluation

# %%
from bellek.musique.eval import calculate_metrics, compare_answers

df['predicted_answer'] = df['predicted_answer'].map(lambda x: x or "N/A")
df = compare_answers(df)
scores = calculate_metrics(df)
scores['fuzzy_match'] = df['fuzzy_match'].mean()
print(scores)
# Out:
# {'exact_match': 0.05, 'f1': 0.1432119305268393, 'fuzzy_match': 0.18}

# %%
df
# Out:
#                       id                                         paragraphs  \
# 0    2hop__131818_161450  [{'idx': 0, 'title': 'Maria Carrillo High Scho...
# 1     2hop__444265_82341  [{'idx': 0, 'title': 'Ocala, Florida', 'paragr...
# 2    2hop__711946_269414  [{'idx': 0, 'title': 'Wild Thing (Tone Lōc son...
# 3    2hop__311931_417706  [{'idx': 0, 'title': 'The Main Attraction (alb...
# 4    2hop__809785_606637  [{'idx': 0, 'title': 'The Main Attraction (alb...
# ..                   ...                                                ...
# 195   2hop__123166_47134  [{'idx': 0, 'title': 'Jesse Alexander', 'parag...
# 196  2hop__312223_144857  [{'idx': 0, 'title': 'Steve Somers', 'paragrap...
# 197   2hop__51965_165532  [{'idx': 0, 'title': 'The Big Arvo', 'paragrap...
# 198  2hop__168816_144857  [{'idx': 0, 'title': 'Minstrel Point', 'paragr...
# 199  2hop__543853_124498  [{'idx': 0, 'title': 'Ahmet Zappa', 'paragraph...
#
#                                                 answer  \
# 0    in the north-east of the country south of the ...
# 1                                  in Northern Florida
# 2                                      Kill Rock Stars
# 3                                        Attic Records
# 4                                  Secret City Records
# ..                                                 ...
# 195                                       Benny Beaver
# 196                                         Clatskanie
# 197                                     Sherry Boucher
# 198                                         Clatskanie
# 199                                       Louis Chedid
#
#                                         answer_aliases  answerable  \
# 0    [in the north-east of the country south of the...        True
# 1              [Northern Florida, in Northern Florida]        True
# 2                                    [Kill Rock Stars]        True
# 3                               [Attic, Attic Records]        True
# 4                                [Secret City Records]        True
# ..                                                 ...         ...
# 195                                     [Benny Beaver]        True
# 196                   [Clatskanie, Oregon, Clatskanie]        True
# 197                                   [Sherry Boucher]        True
# 198                   [Clatskanie, Oregon, Clatskanie]        True
# 199                                     [Louis Chedid]        True
#
#                                               question  \
# 0              Where is the Voshmgir District located?
# 1    In what part of Florida is Tom Denney's birthp...
# 2    What record label is the performer who release...
# 3    What record label does the performer of Emotio...
# 4    What record label does the performer of Advent...
# ..                                                 ...
# 195  What is the mascot of William J. Ripple's univ...
# 196  What city was the author of What We Talk About...
# 197  Who is the spouse of the actor who plays Paul ...
# 198      In what city was the author of Elephant born?
# 199         Who is the father of the Labo M performer?
#
#                                 question_decomposition  \
# 0    [{'question': 'Which country is the Voshmgir D...
# 1    [{'question': 'Where is Tom Denney's birthplac...
# 2    [{'question': 'Who is the performer that relea...
# 3    [{'question': 'Who is the performer of Emotion...
# 4    [{'question': 'Who is the performer of Adventu...
# ..                                                 ...
# 195  [{'question': 'What is the name of William J. ...
# 196  [{'question': 'Who is the author of What We Ta...
# 197  [{'question': 'Who plays Paul in Breakfast at ...
# 198  [{'question': 'Who is the author of Elephant?'...
# 199  [{'question': 'Who is the Labo M performer?'},...
#
#                              predicted_answer  \
# 0                              Not applicable
# 1                            Northern Florida
# 2
# 3
# 4
# ..                                        ...
# 195  Oregon State University and Benny Beaver
# 196
# 197
# 198
# 199
#
#                                         raw_llm_output  exact_match  \
# 0    Reasoning: \nThe context information provides ...        False
# 1    Reasoning: \nTom Denney is an American musicia...         True
# 2    Reasoning: \nThe context information provides ...        False
# 3    Reasoning: \nThe context information provides ...        False
# 4    Reasoning: \nThe context information provides ...        False
# ..                                                 ...          ...
# 195  Reasoning: \nWe are looking for the university...        False
# 196  Reasoning: \nThe context information provides ...        False
# 197  Reasoning: \nWe are looking for the actor who ...        False
# 198  Reasoning: \nThe context information provides ...        False
# 199  Reasoning: \nThe context information mentions ...        False
#
#      fuzzy_match
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
# ..           ...
# 195         True
# 196         True
# 197         True
# 198         True
# 199         True
#
# [200 rows x 11 columns]
