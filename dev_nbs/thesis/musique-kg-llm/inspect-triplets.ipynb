# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from pathlib import Path

import pandas as pd

from bellek.utils import set_seed

set_seed(42)

# %%
DATA_DIRECTORY = Path('/Users/bdsaglam/dev/repos/bellek/data')

# %%
jerx_inference_df = pd.read_json(DATA_DIRECTORY / 'raw/musique-evaluation/jerx-inferences/llama3-base.jsonl', lines=True)
jerx_inference_df.set_index("id", inplace=True)

# %%
record_df = jerx_inference_df.loc['2hop__235471_565925']
record_df
# Out:
#                      paragraph_idx  \
# id
# 2hop__235471_565925              0
# 2hop__235471_565925              1
# 2hop__235471_565925              2
# 2hop__235471_565925              3
# 2hop__235471_565925              4
# 2hop__235471_565925              5
# 2hop__235471_565925              6
# 2hop__235471_565925              7
# 2hop__235471_565925              8
# 2hop__235471_565925              9
# 2hop__235471_565925             10
# 2hop__235471_565925             11
# 2hop__235471_565925             12
# 2hop__235471_565925             13
# 2hop__235471_565925             14
# 2hop__235471_565925             15
# 2hop__235471_565925             16
# 2hop__235471_565925             17
# 2hop__235471_565925             18
# 2hop__235471_565925             19
#
#                                                         paragraph_text  \
# id
# 2hop__235471_565925  The Place and the Time is a compilation album ...
# 2hop__235471_565925  The Main Attraction is an album by American ja...
# 2hop__235471_565925  Plenty, Plenty Soul is an album by American ja...
# 2hop__235471_565925  ``Tootsee Roll ''Single by 69 Boyz from the al...
# 2hop__235471_565925  Mick Taylor Taylor performing with The Rolling...
# 2hop__235471_565925  It's What's Happenin' (subtitled The Varitone ...
# 2hop__235471_565925  Great Grape is a compilation album released by...
# 2hop__235471_565925  Something Personal is an album by American jaz...
# 2hop__235471_565925  Groovin' with Golson is the sixth album by sax...
# 2hop__235471_565925  The Jazz Skyline is an album by American jazz ...
# 2hop__235471_565925  Three for Shepp is the debut album by American...
# 2hop__235471_565925  2 Horns / 2 Rhythm is an album by American jaz...
# 2hop__235471_565925  Foolin' Myself is an album of trio performance...
# 2hop__235471_565925  Immanu El started as a musical experiment in 2...
# 2hop__235471_565925  Soundsigns is an album by the American jazz sa...
# 2hop__235471_565925  Crystal is an album by American jazz pianist A...
# 2hop__235471_565925  More Blues and the Abstract Truth is an album ...
# 2hop__235471_565925  Waterfalls is a live album by American saxopho...
# 2hop__235471_565925  Jazz Contemporary is an album by American jazz...
# 2hop__235471_565925  First Light is an album by jazz trumpeter Fred...
#
#                                          paragraph_title  is_supporting  \
# id
# 2hop__235471_565925               The Place and the Time           True
# 2hop__235471_565925          The Main Attraction (album)          False
# 2hop__235471_565925                  Plenty, Plenty Soul          False
# 2hop__235471_565925                         Tootsee Roll          False
# 2hop__235471_565925                          Mick Taylor          False
# 2hop__235471_565925                It's What's Happenin'          False
# 2hop__235471_565925                          Great Grape           True
# 2hop__235471_565925                   Something Personal          False
# 2hop__235471_565925                 Groovin' with Golson          False
# 2hop__235471_565925                     The Jazz Skyline          False
# 2hop__235471_565925                      Three for Shepp          False
# 2hop__235471_565925                   2 Horns / 2 Rhythm          False
# 2hop__235471_565925                       Foolin' Myself          False
# 2hop__235471_565925                            Immanu El          False
# 2hop__235471_565925                           Soundsigns          False
# 2hop__235471_565925          Crystal (Ahmad Jamal album)          False
# 2hop__235471_565925    More Blues and the Abstract Truth          False
# 2hop__235471_565925                   Waterfalls (album)          False
# 2hop__235471_565925                    Jazz Contemporary          False
# 2hop__235471_565925  First Light (Freddie Hubbard album)          False
#
#                                                                   text  \
# id
# 2hop__235471_565925  # The Place and the Time\nThe Place and the Ti...
# 2hop__235471_565925  # The Main Attraction (album)\nThe Main Attrac...
# 2hop__235471_565925  # Plenty, Plenty Soul\nPlenty, Plenty Soul is ...
# 2hop__235471_565925  # Tootsee Roll\n``Tootsee Roll ''Single by 69 ...
# 2hop__235471_565925  # Mick Taylor\nMick Taylor Taylor performing w...
# 2hop__235471_565925  # It's What's Happenin'\nIt's What's Happenin'...
# 2hop__235471_565925  # Great Grape\nGreat Grape is a compilation al...
# 2hop__235471_565925  # Something Personal\nSomething Personal is an...
# 2hop__235471_565925  # Groovin' with Golson\nGroovin' with Golson i...
# 2hop__235471_565925  # The Jazz Skyline\nThe Jazz Skyline is an alb...
# 2hop__235471_565925  # Three for Shepp\nThree for Shepp is the debu...
# 2hop__235471_565925  # 2 Horns / 2 Rhythm\n2 Horns / 2 Rhythm is an...
# 2hop__235471_565925  # Foolin' Myself\nFoolin' Myself is an album o...
# 2hop__235471_565925  # Immanu El\nImmanu El started as a musical ex...
# 2hop__235471_565925  # Soundsigns\nSoundsigns is an album by the Am...
# 2hop__235471_565925  # Crystal (Ahmad Jamal album)\nCrystal is an a...
# 2hop__235471_565925  # More Blues and the Abstract Truth\nMore Blue...
# 2hop__235471_565925  # Waterfalls (album)\nWaterfalls is a live alb...
# 2hop__235471_565925  # Jazz Contemporary\nJazz Contemporary is an a...
# 2hop__235471_565925  # First Light (Freddie Hubbard album)\nFirst L...
#
#                                                                  input  \
# id
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
# 2hop__235471_565925  [{'content': 'You are an excellent knowledge g...
#
#                                                             generation
# id
# 2hop__235471_565925  The Place and the Time | type | compilation al...
# 2hop__235471_565925  The Main Attraction (album) | genre | Jazz\nTh...
# 2hop__235471_565925  Plenty, Plenty Soul | album | Plenty, Plenty S...
# 2hop__235471_565925  Tootsee Roll | artist | 69 Boyz\nTootsee Roll ...
# 2hop__235471_565925  Mick Taylor | birth name | Michael Kevin Taylo...
# 2hop__235471_565925  It's What's Happenin' | album of | Clark Terry...
# 2hop__235471_565925  Great Grape | compilation album | Columbia Rec...
# 2hop__235471_565925  Something Personal | album by | Jack Wilson\nS...
# 2hop__235471_565925  Groovin' with Golson | album of | Benny Golson...
# 2hop__235471_565925  The Jazz Skyline | type | album\nThe Jazz Skyl...
# 2hop__235471_565925  Three for Shepp | album type | debut\nMarion B...
# 2hop__235471_565925  2 Horns / 2 Rhythm | album | Kenny Dorham\nKen...
# 2hop__235471_565925  Foolin' Myself | album of | Jaki Byard\nFoolin...
# 2hop__235471_565925  Immanu El | start | 2004\nImmanu El | founder ...
# 2hop__235471_565925  Soundsigns | album by | Dewey Redman\nSoundsig...
# 2hop__235471_565925  Crystal (Album) | artist | Ahmad Jamal\nCrysta...
# 2hop__235471_565925  More Blues and the Abstract Truth | album titl...
# 2hop__235471_565925  Waterfalls (album) | type | Live album\nWaterf...
# 2hop__235471_565925  Jazz Contemporary | album by | Kenny Dorham\nJ...
# 2hop__235471_565925  First Light | album by | Freddie Hubbard\nFirs...

# %%
for generation in record_df.iloc[[0, 6]]['generation'].values:
    print(generation)
# Out:
# The Place and the Time | type | compilation album
# The Place and the Time | content | demos, outtakes, alternative versions, live versions
# The Place and the Time | artist | Moby Grape
# The Place and the Time | release year | 2009
# The Place and the Time | format | CD, double LP
# Great Grape | compilation album | Columbia Records
# Great Grape | release year | 1972
# Great Grape | source albums | Moby Grape, Wow, Moby Grape '69
# Moby Grape | album | Columbia Records
# 20 Granite Creek | album | Reprise Records
