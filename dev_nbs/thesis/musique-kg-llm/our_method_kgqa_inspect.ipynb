# %%
import json
import logging
from copy import deepcopy
from datetime import datetime
from functools import partial
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
from tqdm.auto import tqdm
from IPython.display import clear_output

from bellem.utils import set_seed

load_dotenv()

tqdm.pandas()
pd.options.display.float_format = "{:,.3f}".format

set_seed(89)

# %%
import textwrap

def format_paragraph(paragraph):
    return f"Paragraph {paragraph['idx']} - {paragraph['paragraph_text']}"

def present_row(row):
    outcome = "Success" if row['fuzzy_match'] else "Fail"
    print(row['id'])
    print(f"Outcome: {outcome}")
    print()
    print("# Question decomposition")
    print("## Reference")
    print(row['question'])
    for item in row['question_decomposition_original']:
        q = item['question']
        a = item['answer']
        print(f"\t{q}")
        print(f"\t\t{a}")
    print()
    print("## Prediction")
    for item in row['question_decomposition']:
        q = item['question']
        a = item['answer']
        print(f"\t{q}")
        print(f"\t\t{a}")
    print()
    print("# Answer")
    print(f"Reference: {row['answers']}")
    print(f"Prediction: {row['predicted_answer']}")
    print()
    print("# Context")
    print("# Reference")
    for p in row['paragraphs_original']:
        if p['is_supporting']:
            for line in textwrap.wrap(format_paragraph(p), width=120):
                print(line)
            print()

    print("# Prediction")
    for p in row['paragraphs']:
        if p['is_supporting']:
            for line in textwrap.wrap(format_paragraph(p), width=120):
                print(line)
            print()

# %%
def partition_by_success(dataf):
    fail_dataf = dataf.loc[~dataf['fuzzy_match']]
    success_dataf = dataf.loc[dataf['fuzzy_match']]
    print(len(success_dataf), len(fail_dataf))
    print(f"{len(success_dataf)/len(dataf):.2f}", f"{len(fail_dataf)/len(dataf):.2f}")
    return success_dataf, fail_dataf

# %%
res_df = pd.read_json('our-method-kgqa-results-20240908-134424.jsonl', lines=True)
original_df = pd.read_json("../../data/generated/musique-evaluation/dataset.jsonl", orient="records", lines=True)
df = pd.merge(res_df, original_df[['id', 'paragraphs', 'question_decomposition']], on="id", suffixes=("", "_original"))
df.head()
# Out:
#                     id                                         paragraphs  \
# 0  2hop__575188_342798  [{'idx': 0, 'title': '', 'paragraph_text': 'Li...
# 1  2hop__731584_700117  [{'idx': 0, 'title': '', 'paragraph_text': 'KA...
# 2  2hop__690412_526810  [{'idx': 0, 'title': '', 'paragraph_text': 'Ca...
# 3   2hop__263638_69048  [{'idx': 0, 'title': '', 'paragraph_text': 'Mi...
# 4   2hop__142842_68489  [{'idx': 0, 'title': '', 'paragraph_text': 'Pe...
#
#                             answer                     answer_aliases  \
# 0                 Ahmad Shah Qajar                 [Ahmad Shah Qajar]
# 1                   Berrien County                   [Berrien County]
# 2                Chao Phraya River                [Chao Phraya River]
# 3  Honorable Justice Abiodun Smith  [Honorable Justice Abiodun Smith]
# 4                   Snapper Foster                   [Snapper Foster]
#
#    answerable                            answers  \
# 0        True                 [Ahmad Shah Qajar]
# 1        True                   [Berrien County]
# 2        True                [Chao Phraya River]
# 3        True  [Honorable Justice Abiodun Smith]
# 4        True                   [Snapper Foster]
#
#                                             question  \
# 0        Who is the child of Mahmoud Mirza's father?
# 1  In which county is the city to which KKVU is l...
# 2  For what river does the river on which Pa Sak ...
# 3  Who is the Chief Judge of the Tebesa Nemine's ...
# 4  Who did the performer of Night Rocker play on ...
#
#                               question_decomposition  \
# 0  [{'id': 575188, 'question': 'Who is Mahmoud Mi...
# 1  [{'id': 731584, 'question': 'To which city is ...
# 2  [{'id': 690412, 'question': 'On which river is...
# 3  [{'id': 263638, 'question': 'Where was Tebesa ...
# 4  [{'id': 142842, 'question': 'Who performed Nig...
#
#                                         triplets_str  \
# 0  [Liliana Mumy | father | Bill Mumy\nBill Mumy ...
# 1  [KAPE | broadcast frequency | 1550 AM\nKAPE | ...
# 2  [Cabramatta Creek | location | Sydney\nCabrama...
# 3  [Michael J. Barron | birth year | 1933\nMichae...
# 4  [Perfect Night: Live in London | recorded by |...
#
#                 predicted_answer  \
# 0  Amanollah Khan Zia' os-Soltan
# 1                 Berrien County
# 2              Chao Phraya River
# 3                 Not applicable
# 4                 Snapper Foster
#
#                                           raw_output  exact_match  \
# 0  {'answer': 'Amanollah Khan Zia' os-Soltan', 'h...        False
# 1  {'answer': 'Berrien County', 'hops': [{'questi...         True
# 2  {'answer': 'Chao Phraya River', 'hops': [{'que...         True
# 3  {'answer': 'Not applicable', 'hops': [{'questi...        False
# 4  {'answer': 'Snapper Foster', 'hops': [{'questi...         True
#
#    fuzzy_match                                paragraphs_original  \
# 0        False  [{'idx': 0, 'title': 'Liliana Mumy', 'paragrap...
# 1         True  [{'idx': 0, 'title': 'KAPE', 'paragraph_text':...
# 2         True  [{'idx': 0, 'title': 'Cabramatta Creek', 'para...
# 3        False  [{'idx': 0, 'title': 'Michael J. Barron', 'par...
# 4         True  [{'idx': 0, 'title': 'Perfect Night: Live in L...
#
#                      question_decomposition_original
# 0  [{'id': 575188, 'question': 'Mahmoud Mirza >> ...
# 1  [{'id': 731584, 'question': 'KKVU >> licensed ...
# 2  [{'id': 690412, 'question': 'Pa Sak Jolasid Da...
# 3  [{'id': 263638, 'question': 'Tebesa Nemine >> ...
# 4  [{'id': 142842, 'question': 'Which performer r...

# %%
success_df, fail_df = partition_by_success(df)
# Out:
# 68 32
# 0.68 0.32

# %%
i = 0
row = fail_df.iloc[i]
present_row(row)
# Out:
# 2hop__575188_342798
# Outcome: Fail
#
# # Question decomposition
# ## Reference
# Who is the child of Mahmoud Mirza's father?
# 	Mahmoud Mirza >> father
# 		Mohammad Ali Shah Qajar
# 	#1 >> child
# 		Ahmad Shah Qajar
#
# ## Prediction
# 	Who is Mahmoud Mirza's father?
# 		Mohammad Ali Shah Qajar
# 	Who is the child of #1?
# 		Ahmad Shah Qajar
#
# # Answer
# Reference: ['Ahmad Shah Qajar']
# Prediction: Amanollah Khan Zia' os-Soltan
#
# # Context
# # Reference
# Paragraph 7 - Amanollah Khan Zia' os-Soltan (also Amanollah Khan Donboli "Nazer ol-Ayaleh" "Zia' os-Soltan") was an
# Iranian aristocrat and politician at Qajar court during the time of Mozaffar ad-Din Shah, Mohammad Ali Shah and Ahmad
# Shah Qajar and hero of the Persian Constitutional Revolution.
#
# Paragraph 8 - Mahmoud Mirza (9 October 1905 – 2 July 1988) Iranian prince of Qajar Dynasty, was the son of Mohammad Ali
# Shah Qajar.
#
# # Prediction
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | title | Nazer ol-Ayaleh
#
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | title | Zia' os-Soltan
#
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | profession | politician
#
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | profession | aristocrat
#
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | affiliation | Qajar court
#
# Paragraph 7 - Amanollah Khan Zia' os-Soltan | affiliation | Persian Constitutional Revolution | hero
#
# Paragraph 8 - Mahmoud Mirza | birth date | 9 October 1905
#
# Paragraph 8 - Mahmoud Mirza | death date | 2 July 1988
#
# Paragraph 8 - Mahmoud Mirza | dynasty | Qajar

# %%
failure_reasons = {}

# %%
for i in range(len(fail_df.sort_values('id'))):
    row = fail_df.iloc[i]
    id = row['id']
    if id in failure_reasons:
        continue
    print(f"{len(failure_reasons)} / {len(fail_df)}")
    present_row(row)
    reason = input("Reason: ")
    if reason.lower() == 'quit':
        break
    failure_reasons[id] = reason
    clear_output(wait=True)

# %%
failure_reasons
# Out:
# {'2hop__575188_342798': 'missing triplet; father of Mahmoud Mirza',
#  '2hop__263638_69048': 'missing triplet (temporal); former chief vs current chief',
#  '2hop__6736_6733': 'poor qa; answers the first sub-q',
#  '2hop__128420_375952': 'poor qa; location vs broadcasting area',
#  '2hop__582045_161450': 'poor qa; answers the first sub-q',
#  '2hop__607517_161450': 'partially correct',
#  '2hop__310456_846599': 'ambiguous question',
#  '2hop__199513_13732': 'missing triplet; age of Mary when engaged to Joseph',
#  '2hop__472083_7298': 'missing triplet; illuminations | performer & no relation as "start career alongside Josh Groban"',
#  '2hop__785711_73244': 'ambiguous answer',
#  '2hop__75169_92673': 'missing triplet; no direct triplet for meridian | reference | north pole',
#  '2hop__157251_556157': 'poor qa & ambigous triplet; "serve as the mouth of" ~= "tributary of"',
#  '2hop__477492_240386': 'missing triplets & 3-hop; no triplet for Triumph | record label | TML Entertainment and this is a 3-hop questions Gil Moore >> Triumph >> TML Entertainment',
#  '2hop__333020_69048': 'ambigous triplets;  Rosaline Bozimo | position | Chief Justice of Delta State and Orezi | state of origin | Delta State',
#  '2hop__149983_108549': 'missing triplet; Doctor Fate | character in | Smallville',
#  '2hop__280451_84616': 'poor answering; the answer contains 12 words, we had prompted LLM for 2-4 answers',
#  '2hop__226204_69048': "missing triplet (temporal); Rosaline Bozimo was Chief but now it's Honorable Justice Abiodun Smith.",
#  '2hop__128342_375952': 'poor qa; sufficient triplets',
#  '2hop__131818_161450': 'ambigous statement in context; Golestān Province (Persian: استان گلستان\u200e, Ostān-e Golestān) is one of the 31 provinces of Iran, located in the north-east of the country south of the Caspian Sea.',
#  '2hop__711946_269414': 'ambigous question; what does record label mean?',
#  '2hop__797443_120537': 'missing triplet & wrong question; British Aerospace 146 | manufacturer | British Aerospace',
#  '2hop__481809_184805': 'poor qa; ambiguous triplet (Buckpasser | sire | Tom Fool)',
#  '2hop__278022_71701': 'missing triplet; (Wang Yue | death place | Foshan, Guangdong)',
#  '2hop__418941_429437': 'poor qa & ambigous triplets; "mouth of" ~= "tributary of"',
#  '2hop__307218_161450': 'ambiguous context; Golestān Province (Persian: استان گلستان\u200e, Ostān-e Golestān) is one of the 31 provinces of Iran, located in the north-east of the country south of the Caspian Sea.',
#  '2hop__130984_55721': 'missing triplet; Coast Range | most rain in | Oregon',
#  '2hop__363216_787353': 'poor qa & ambiguous triplets; answers the first sub-question',
#  '2hop__358582_189042': '3 hop & ambiguous question; record label of artist or record label of album',
#  '2hop__136067_160249': 'missing triplet & poor triplets; Pyrrhus war | period | 323–272 BC',
#  '2hop__304852_758385': 'missing triplet;  (Park Rapids | administrative territorial entity | Hubbard County) this is an indirect information to be inferred from the context',
#  '2hop__279729_20057': 'missing triplet; Free Software Foundation | founded by | Richard Stallman',
#  '2hop__726717_610238': 'partially correct'}

# %%
with open('kgqa-inspect-failure-reasons.json', 'w') as f:
    json.dump(failure_reasons, f, indent=2)

# %%
inspect_df = pd.DataFrame(failure_reasons.items(), columns=['id', 'note']).set_index('id')
inspect_df['failure_category'] = inspect_df['note'].map(lambda x: x.split(";")[0])

# %%
def map_primary_reason(category):
    if "temporal" in category:
        return "temporal"
    if "missing triplet" in category:
        return "missing triplet"
    if "poor qa" in category:
        return "poor qa"
    if "ambi" in category and "triplet" in category:
        return "triplet quality"
    if "3" in category:
        return "3-hop"
    if "poor qa" in category:
        return "poor reasoning"
    if "question" in category:
        return "problematic question"
    if "context" in category:
        return "problematic context"
    return category

# %%
inspect_df['primary'] = inspect_df['failure_category'].map(map_primary_reason)

# %%
sorted(inspect_df['primary'].values.tolist())
# Out:
# ['3-hop',
#  'ambiguous answer',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'missing triplet',
#  'partially correct',
#  'partially correct',
#  'poor answering',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'poor qa',
#  'problematic context',
#  'problematic context',
#  'problematic question',
#  'problematic question',
#  'temporal',
#  'temporal',
#  'triplet quality']

# %%
inspect_df['primary'].value_counts()
# Out:
# primary
# missing triplet         12
# poor qa                  8
# temporal                 2
# partially correct        2
# problematic question     2
# problematic context      2
# ambiguous answer         1
# triplet quality          1
# poor answering           1
# 3-hop                    1
# Name: count, dtype: int64

# %%
12 / len(fail_df)
# Out:
# 0.375

# %%
8 / len(fail_df)
# Out:
# 0.25

# %%
2 / len(fail_df)
# Out:
# 0.0625

# %%
inspect_df
# Out:
#                                                                   note  \
# id
# 2hop__575188_342798           missing triplet; father of Mahmoud Mirza
# 2hop__263638_69048   missing triplet (temporal); former chief vs cu...
# 2hop__6736_6733                       poor qa; answers the first sub-q
# 2hop__128420_375952             poor qa; location vs broadcasting area
# 2hop__582045_161450                   poor qa; answers the first sub-q
# 2hop__607517_161450                                  partially correct
# 2hop__310456_846599                                 ambiguous question
# 2hop__199513_13732   missing triplet; age of Mary when engaged to J...
# 2hop__472083_7298    missing triplet; illuminations | performer & n...
# 2hop__785711_73244                                    ambiguous answer
# 2hop__75169_92673    missing triplet; no direct triplet for meridia...
# 2hop__157251_556157  poor qa & ambigous triplet; "serve as the mout...
# 2hop__477492_240386  missing triplets & 3-hop; no triplet for Trium...
# 2hop__333020_69048   ambigous triplets;  Rosaline Bozimo | position...
# 2hop__149983_108549  missing triplet; Doctor Fate | character in | ...
# 2hop__280451_84616   poor answering; the answer contains 12 words, ...
# 2hop__226204_69048   missing triplet (temporal); Rosaline Bozimo wa...
# 2hop__128342_375952                       poor qa; sufficient triplets
# 2hop__131818_161450  ambigous statement in context; Golestān Provin...
# 2hop__711946_269414    ambigous question; what does record label mean?
# 2hop__797443_120537  missing triplet & wrong question; British Aero...
# 2hop__481809_184805  poor qa; ambiguous triplet (Buckpasser | sire ...
# 2hop__278022_71701   missing triplet; (Wang Yue | death place | Fos...
# 2hop__418941_429437  poor qa & ambigous triplets; "mouth of" ~= "tr...
# 2hop__307218_161450  ambiguous context; Golestān Province (Persian:...
# 2hop__130984_55721   missing triplet; Coast Range | most rain in | ...
# 2hop__363216_787353  poor qa & ambiguous triplets; answers the firs...
# 2hop__358582_189042  3 hop & ambiguous question; record label of ar...
# 2hop__136067_160249  missing triplet & poor triplets; Pyrrhus war |...
# 2hop__304852_758385  missing triplet;  (Park Rapids | administrativ...
# 2hop__279729_20057   missing triplet; Free Software Foundation | fo...
# 2hop__726717_610238                                  partially correct
#
#                                      failure_category               primary
# id
# 2hop__575188_342798                   missing triplet       missing triplet
# 2hop__263638_69048         missing triplet (temporal)              temporal
# 2hop__6736_6733                               poor qa               poor qa
# 2hop__128420_375952                           poor qa               poor qa
# 2hop__582045_161450                           poor qa               poor qa
# 2hop__607517_161450                 partially correct     partially correct
# 2hop__310456_846599                ambiguous question  problematic question
# 2hop__199513_13732                    missing triplet       missing triplet
# 2hop__472083_7298                     missing triplet       missing triplet
# 2hop__785711_73244                   ambiguous answer      ambiguous answer
# 2hop__75169_92673                     missing triplet       missing triplet
# 2hop__157251_556157        poor qa & ambigous triplet               poor qa
# 2hop__477492_240386          missing triplets & 3-hop       missing triplet
# 2hop__333020_69048                  ambigous triplets       triplet quality
# 2hop__149983_108549                   missing triplet       missing triplet
# 2hop__280451_84616                     poor answering        poor answering
# 2hop__226204_69048         missing triplet (temporal)              temporal
# 2hop__128342_375952                           poor qa               poor qa
# 2hop__131818_161450     ambigous statement in context   problematic context
# 2hop__711946_269414                 ambigous question  problematic question
# 2hop__797443_120537  missing triplet & wrong question       missing triplet
# 2hop__481809_184805                           poor qa               poor qa
# 2hop__278022_71701                    missing triplet       missing triplet
# 2hop__418941_429437       poor qa & ambigous triplets               poor qa
# 2hop__307218_161450                 ambiguous context   problematic context
# 2hop__130984_55721                    missing triplet       missing triplet
# 2hop__363216_787353      poor qa & ambiguous triplets               poor qa
# 2hop__358582_189042        3 hop & ambiguous question                 3-hop
# 2hop__136067_160249   missing triplet & poor triplets       missing triplet
# 2hop__304852_758385                   missing triplet       missing triplet
# 2hop__279729_20057                    missing triplet       missing triplet
# 2hop__726717_610238                 partially correct     partially correct

# %%
inspect_df.loc['2hop__226204_69048']
# Out:
# note                missing triplet (temporal); Rosaline Bozimo wa...
# failure_category                           missing triplet (temporal)
# primary                                                      temporal
# Name: 2hop__226204_69048, dtype: object

# %%
row = fail_df.set_index('id', drop=False).loc['2hop__226204_69048']
row
# Out:
# id                                                                2hop__226204_69048
# paragraphs                         [{'idx': 0, 'title': '', 'paragraph_text': 'Li...
# answer                                               Honorable Justice Abiodun Smith
# answer_aliases                                     [Honorable Justice Abiodun Smith]
# answerable                                                                      True
# answers                                            [Honorable Justice Abiodun Smith]
# question                           Who is the chief judge of Friday Osanebi's bir...
# question_decomposition             [{'id': 226204, 'question': 'Where was Friday ...
# triplets_str                       [List of sitting judges of the Supreme Court o...
# predicted_answer                                                     Rosaline Bozimo
# raw_output                         {'answer': 'Rosaline Bozimo', 'hops': [{'quest...
# exact_match                                                                    False
# fuzzy_match                                                                    False
# paragraphs_original                [{'idx': 0, 'title': 'List of sitting judges o...
# question_decomposition_original    [{'id': 226204, 'question': 'Friday Osanebi >>...
# Name: 2hop__226204_69048, dtype: object

# %%
present_row(row)
# Out:
# 2hop__226204_69048
# Outcome: Fail
#
# # Question decomposition
# ## Reference
# Who is the chief judge of Friday Osanebi's birthplace?
# 	Friday Osanebi >> place of birth
# 		Delta State
# 	who is the chief judge of #1
# 		Honorable Justice Abiodun Smith
#
# ## Prediction
# 	Where was Friday Osanebi born?
# 		Delta State
# 	Who is the chief judge of #1?
# 		Honorable Justice Abiodun Smith
#
# # Answer
# Reference: ['Honorable Justice Abiodun Smith']
# Prediction: Rosaline Bozimo
#
# # Context
# # Reference
# Paragraph 18 - Friday Ossai Osanebi (born August 7, 1980) is a Nigerian and a member of the Delta State House of
# Assembly the Lawmaker representing Ndokwa East Local Government Constituency in the State House of Assembly.
#
# Paragraph 19 - Rosaline Patricia Irorefe Bozimo (born 1 January 1946) is a Nigerian lawyer who was appointed Chief
# Justice of Delta State with effect from 23 March 2003. She retired on 1 January 2011 and was succeeded by Honorable
# Justice Abiodun Smith.
#
# # Prediction
# Paragraph 18 - Friday Osanebi | birth date | August 7, 1980
#
# Paragraph 18 - Friday Osanebi | nationality | Nigerian
#
# Paragraph 18 - Friday Osanebi | profession | Lawmaker
#
# Paragraph 18 - Friday Osanebi | represented | Ndokwa East Local Government Constituency
#
# Paragraph 18 - Friday Osanebi | represented in | Delta State House of Assembly
#
# Paragraph 19 - Rosaline Bozimo | birth date | January 1, 1946
#
# Paragraph 19 - Rosaline Bozimo | profession | lawyer
#
# Paragraph 19 - Rosaline Bozimo | position | Chief Justice of Delta State
#
# Paragraph 19 - Rosaline Bozimo | tenure start | March 23, 2003
#
# Paragraph 19 - Rosaline Bozimo | retirement date | January 1, 2011
#
# Paragraph 19 - Rosaline Bozimo | successor | Honorable Justice Abiodun Smith
