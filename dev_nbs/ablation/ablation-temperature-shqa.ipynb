# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import json
import pandas as pd
from pathlib import Path
from copy import deepcopy
from functools import partial
import magentic

from bellek.qa.ablation import answer_question_standard, answer_question_cot, answer_question_cot_fs, answer_question_cte, answer_question_cte_cot
from bellek.utils import set_seed, jprint
from bellek.musique.singlehop import benchmark

set_seed(89)

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
N_RUNS = 3
SAMPLE_SIZE = 100

# %%
from bellek.musique.constants import ABLATION_RECORD_IDS

df = pd.read_json('../../data/generated/musique-evaluation/dataset.jsonl', orient='records', lines=True)
df = df.set_index('id', drop=False).loc[ABLATION_RECORD_IDS].copy().reset_index(drop=True)
qd_df = pd.read_json('../../data/generated/musique-evaluation/question-decomposition.jsonl', orient='records', lines=True)
df = pd.merge(df.drop(columns=['question', 'question_decomposition']), qd_df, on='id', suffixes=('', ''))
df = df.head(SAMPLE_SIZE)

print(df.shape)
df.head()
# Out:
# (100, 8)
#                     id                                         paragraphs  \
# 0  2hop__575188_342798  [{'idx': 0, 'title': 'Liliana Mumy', 'paragrap...
# 1  2hop__731584_700117  [{'idx': 0, 'title': 'KAPE', 'paragraph_text':...
# 2  2hop__690412_526810  [{'idx': 0, 'title': 'Cabramatta Creek', 'para...
# 3   2hop__263638_69048  [{'idx': 0, 'title': 'Michael J. Barron', 'par...
# 4   2hop__142842_68489  [{'idx': 0, 'title': 'Perfect Night: Live in L...
#
#                             answer                     answer_aliases  \
# 0                 Ahmad Shah Qajar                 [Ahmad Shah Qajar]
# 1                   Berrien County                   [Berrien County]
# 2                Chao Phraya River                [Chao Phraya River]
# 3  Honorable Justice Abiodun Smith  [Honorable Justice Abiodun Smith]
# 4                   Snapper Foster                   [Snapper Foster]
#
#    answerable                            answers  \
# 0        True                 [Ahmad Shah Qajar]
# 1        True                   [Berrien County]
# 2        True                [Chao Phraya River]
# 3        True  [Honorable Justice Abiodun Smith]
# 4        True                   [Snapper Foster]
#
#                                             question  \
# 0        Who is the child of Mahmoud Mirza's father?
# 1  In which county is the city to which KKVU is l...
# 2  For what river does the river on which Pa Sak ...
# 3  Who is the Chief Judge of the Tebesa Nemine's ...
# 4  Who did the performer of Night Rocker play on ...
#
#                               question_decomposition
# 0  [{'id': 575188, 'question': 'Who is Mahmoud Mi...
# 1  [{'id': 731584, 'question': 'To which city is ...
# 2  [{'id': 690412, 'question': 'On which river is...
# 3  [{'id': 263638, 'question': 'Where was Tebesa ...
# 4  [{'id': 142842, 'question': 'Who performed Nig...

# %%
perfect_retrieval_func = lambda docs, query: [doc for doc in docs if doc['is_supporting']]

# %%
results = []

# %%
for temperature in [0.0, 0.1, 0.3, 0.5, 0.7, 0.9]:
    with magentic.OpenaiChatModel("gpt-3.5-turbo", temperature=temperature):
        for qa_prompting, qa_func in [('standard', answer_question_standard), ('cte', answer_question_cte)]:
            for i in range(1, N_RUNS+1):
                _, scores = benchmark(df, qa_func, perfect_retrieval_func, ignore_errors=True)
                results.append({**scores, "retrieval": "groundtruth", "context": "paragraphs", "qa": qa_prompting, "temperature": temperature, "run": i})
                jprint(scores)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.55,
#   "f1": 0.6496479925303454,
#   "fuzzy_match": 0.68
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.57,
#   "f1": 0.6637432306255835,
#   "fuzzy_match": 0.7
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.56,
#   "f1": 0.663219421101774,
#   "fuzzy_match": 0.69
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.62,
#   "f1": 0.733314659197012,
#   "fuzzy_match": 0.77
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.64,
#   "f1": 0.7391720969089388,
#   "fuzzy_match": 0.76
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.63,
#   "f1": 0.727347848230201,
#   "fuzzy_match": 0.75
# }

# %% [markdown]
# # Report

# %%
report_df = pd.DataFrame.from_records(results, columns=['context', 'retrieval', 'qa', 'temperature', 'run', 'exact_match', 'f1'])
report_df
# Out:
#        context    retrieval        qa  temperature  run  exact_match    f1
# 0   paragraphs  groundtruth  standard        0.100    1        0.560 0.669
# 1   paragraphs  groundtruth  standard        0.100    2        0.580 0.675
# 2   paragraphs  groundtruth  standard        0.100    3        0.580 0.674
# 3   paragraphs  groundtruth       cte        0.100    1        0.630 0.738
# 4   paragraphs  groundtruth       cte        0.100    2        0.620 0.722
# 5   paragraphs  groundtruth       cte        0.100    3        0.620 0.729
# 6   paragraphs  groundtruth  standard        0.300    1        0.560 0.666
# 7   paragraphs  groundtruth  standard        0.300    2        0.580 0.679
# 8   paragraphs  groundtruth  standard        0.300    3        0.560 0.665
# 9   paragraphs  groundtruth       cte        0.300    1        0.610 0.719
# 10  paragraphs  groundtruth       cte        0.300    2        0.620 0.734
# 11  paragraphs  groundtruth       cte        0.300    3        0.660 0.754
# 12  paragraphs  groundtruth  standard        0.500    1        0.560 0.661
# 13  paragraphs  groundtruth  standard        0.500    2        0.570 0.664
# 14  paragraphs  groundtruth  standard        0.500    3        0.570 0.666
# 15  paragraphs  groundtruth       cte        0.500    1        0.620 0.732
# 16  paragraphs  groundtruth       cte        0.500    2        0.620 0.730
# 17  paragraphs  groundtruth       cte        0.500    3        0.630 0.734
# 18  paragraphs  groundtruth  standard        0.700    1        0.580 0.675
# 19  paragraphs  groundtruth  standard        0.700    2        0.570 0.671
# 20  paragraphs  groundtruth  standard        0.700    3        0.550 0.656
# 21  paragraphs  groundtruth       cte        0.700    1        0.640 0.733
# 22  paragraphs  groundtruth       cte        0.700    2        0.610 0.718
# 23  paragraphs  groundtruth       cte        0.700    3        0.630 0.726
# 24  paragraphs  groundtruth  standard        0.900    1        0.550 0.662
# 25  paragraphs  groundtruth  standard        0.900    2        0.570 0.671
# 26  paragraphs  groundtruth  standard        0.900    3        0.560 0.662
# 27  paragraphs  groundtruth       cte        0.900    1        0.630 0.734
# 28  paragraphs  groundtruth       cte        0.900    2        0.600 0.706
# 29  paragraphs  groundtruth       cte        0.900    3        0.660 0.758
# 30  paragraphs  groundtruth  standard        0.000    1        0.550 0.650
# 31  paragraphs  groundtruth  standard        0.000    2        0.570 0.664
# 32  paragraphs  groundtruth  standard        0.000    3        0.560 0.663
# 33  paragraphs  groundtruth       cte        0.000    1        0.620 0.733
# 34  paragraphs  groundtruth       cte        0.000    2        0.640 0.739
# 35  paragraphs  groundtruth       cte        0.000    3        0.630 0.727

# %%
from datetime import datetime
suffix = datetime.utcnow().strftime("%Y%m%d-%H%M%S")
report_df.to_json(f'./ablation-temperature-{suffix}.jsonl', orient='records', lines=True)

# %%
report_df.drop(columns=['context', 'retrieval', 'run']).groupby(['qa']).mean().loc[['standard', 'cte']]
# Out:
#           temperature  exact_match    f1
# qa
# standard        0.417        0.566 0.666
# cte             0.417        0.627 0.731

# %%
report_df.drop(columns=['context', 'retrieval', 'run']).groupby(['qa', 'temperature']).mean()
# Out:
#                       exact_match    f1
# qa       temperature
# cte      0.000              0.630 0.733
#          0.100              0.623 0.729
#          0.300              0.630 0.736
#          0.500              0.623 0.732
#          0.700              0.627 0.726
#          0.900              0.630 0.733
# standard 0.000              0.560 0.659
#          0.100              0.573 0.673
#          0.300              0.567 0.670
#          0.500              0.567 0.663
#          0.700              0.567 0.667
#          0.900              0.560 0.665

# %%
print(report_df.drop(columns=['context', 'retrieval', 'run']).groupby(['qa', 'temperature']).mean().to_latex())
# Out:
# \begin{tabular}{llrr}
# \toprule
#  &  & exact_match & f1 \\
# qa & temperature &  &  \\
# \midrule
# \multirow[t]{6}{*}{cte} & 0.000000 & 0.630000 & 0.733278 \\
#  & 0.100000 & 0.623333 & 0.729475 \\
#  & 0.300000 & 0.630000 & 0.735729 \\
#  & 0.500000 & 0.623333 & 0.731715 \\
#  & 0.700000 & 0.626667 & 0.725516 \\
#  & 0.900000 & 0.630000 & 0.732523 \\
# \cline{1-4}
# \multirow[t]{6}{*}{standard} & 0.000000 & 0.560000 & 0.658870 \\
#  & 0.100000 & 0.573333 & 0.672759 \\
#  & 0.300000 & 0.566667 & 0.670046 \\
#  & 0.500000 & 0.566667 & 0.663426 \\
#  & 0.700000 & 0.566667 & 0.667299 \\
#  & 0.900000 & 0.560000 & 0.664886 \\
# \cline{1-4}
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Inspect

# %%
i = 2
row = df_cot.iloc[i]
hop = row['raw_output']['hops'][0]
print(row['question'])
print(row['answers'])
print(hop['llm_output'].answer)
print(hop['llm_output'].reasoning)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 i = 2
# ----> 2 row = df_cot.iloc[i]
#       3 hop = row['raw_output']['hops'][0]
#       4 print(row['question'])
#
# NameError: name 'df_cot' is not defined
