# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import json
import pandas as pd
from pathlib import Path
from copy import deepcopy
from functools import partial

from bellek.musique.qa import answer_question_standard
from bellek.utils import set_seed, jprint
from bellek.musique.singlehop import benchmark

set_seed(89)

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
from bellek.musique.constants import ABLATION_RECORD_IDS

df = pd.read_json('../../data/generated/musique-evaluation/dataset.jsonl', orient='records', lines=True)
df = df.set_index('id', drop=False).loc[ABLATION_RECORD_IDS].copy().reset_index(drop=True)

print(len(df))
df.head()
# Out:
# 100
#                     id                                         paragraphs  \
# 0  2hop__575188_342798  [{'idx': 0, 'title': 'Liliana Mumy', 'paragrap...
# 1  2hop__731584_700117  [{'idx': 0, 'title': 'KAPE', 'paragraph_text':...
# 2  2hop__690412_526810  [{'idx': 0, 'title': 'Cabramatta Creek', 'para...
# 3   2hop__263638_69048  [{'idx': 0, 'title': 'Michael J. Barron', 'par...
# 4   2hop__142842_68489  [{'idx': 0, 'title': 'Perfect Night: Live in L...
#
#                                             question  \
# 0        Who is the child of Mahmoud Mirza's father?
# 1  In which county is the city to which KKVU is l...
# 2  For what river does the river on which Pa Sak ...
# 3  Who is the Chief Judge of the Tebesa Nemine's ...
# 4  Who did the performer of Night Rocker play on ...
#
#                               question_decomposition  \
# 0  [{'id': 575188, 'question': 'Mahmoud Mirza >> ...
# 1  [{'id': 731584, 'question': 'KKVU >> licensed ...
# 2  [{'id': 690412, 'question': 'Pa Sak Jolasid Da...
# 3  [{'id': 263638, 'question': 'Tebesa Nemine >> ...
# 4  [{'id': 142842, 'question': 'Which performer r...
#
#                             answer                     answer_aliases  \
# 0                 Ahmad Shah Qajar                 [Ahmad Shah Qajar]
# 1                   Berrien County                   [Berrien County]
# 2                Chao Phraya River                [Chao Phraya River]
# 3  Honorable Justice Abiodun Smith  [Honorable Justice Abiodun Smith]
# 4                   Snapper Foster                   [Snapper Foster]
#
#    answerable                            answers
# 0        True                 [Ahmad Shah Qajar]
# 1        True                   [Berrien County]
# 2        True                [Chao Phraya River]
# 3        True  [Honorable Justice Abiodun Smith]
# 4        True                   [Snapper Foster]

# %%
df['paragraphs'] = df['paragraphs'].map(lambda ps: [p for p in ps if p['is_supporting']])

# %%
perfect_retrieval_func = lambda docs, query: [doc for doc in docs if doc['is_supporting']]

# %%
qa_func = answer_question_standard

# %%
results = []

# %%
completion_params = {
    "temperature": 0.1
}

# %%
def replace_paragraphs_with_offline_triplets(df, jerx_file):
    df = df.copy()

    jerx_df = pd.read_json(jerx_file, lines=True)
    jerx_mapping = {(row['id'], row['paragraph_idx']): row['generation'] for _, row in jerx_df.iterrows()}

    def replace_paragraphs(row):
        new_paragraphs = []
        for p in row['paragraphs']:
            p = deepcopy(p) 
            triplets_str = jerx_mapping[(row['id'], p['idx'])].strip()
            p['paragraph_text'] = triplets_str
            new_paragraphs.append(p)
        row['paragraphs'] = new_paragraphs
        return row

    return df.progress_apply(replace_paragraphs, axis=1)

# %% [markdown]
# ## llama-sft

# %%
jerx_inferences_path = Path('/Users/bdsaglam/dev/repos/bellek/data/raw/musique-evaluation/jerx-inferences/llama3-sft-aw7ihmbc.jsonl')
df_llama_sft = replace_paragraphs_with_offline_triplets(df, jerx_inferences_path)
df_llama_sft.head()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 jerx_inferences_path = Path('/Users/bdsaglam/dev/repos/bellek/data/raw/musique-evaluation/jerx-inferences/llama3-sft-aw7ihmbc.jsonl')
# ----> 2 df_llama_sft = replace_paragraphs_with_offline_triplets(df, jerx_inferences_path)
#       3 df_llama_sft.head()
#
# Cell In[10], line 17, in replace_paragraphs_with_offline_triplets(df, jerx_file)
#      14     row['paragraphs'] = new_paragraphs
#      15     return row
# ---> 17 return df.progress_apply(replace_paragraphs, axis=1)
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~/dev/repos/bellek/.venv/lib/python3.10/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[10], line 11, in replace_paragraphs_with_offline_triplets.<locals>.replace_paragraphs(row)
#       9 for p in row['paragraphs']:
#      10     p = deepcopy(p)
# ---> 11     triplets_str = jerx_mapping[(row['id'], p['idx'])].strip()
#      12     p['paragraph_text'] = triplets_str
#      13     new_paragraphs.append(p)
#
# KeyError: ('2hop__263638_69048', 5)

# %%
for i in range(1,4):
    df_llama_sft, scores = benchmark(df_llama_sft, qa_func, perfect_retrieval_func, ignore_errors=True)
    results.append({**scores, "retrieval": "groundtruth", "context": "triplets", "jerx": "llama-sft", "run": i})
    jprint(scores)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.55,
#   "f1": 0.6413358863358863,
#   "fuzzy_match": 0.66
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.55,
#   "f1": 0.6413358863358863,
#   "fuzzy_match": 0.66
# }
#   0%|          | 0/100 [00:00<?, ?it/s]
# {
#   "exact_match": 0.55,
#   "f1": 0.6413358863358863,
#   "fuzzy_match": 0.66
# }

# %% [markdown]
# # Report

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
report_df = pd.DataFrame.from_records(results, columns=['run', 'context', 'retrieval', 'jerx', 'exact_match', 'fuzzy_match', 'f1'])
report_df.drop(columns=['context', 'retrieval', 'fuzzy_match'])
# Out:
#    run             jerx  exact_match    f1
# 0    1  llama-zero-shot        0.530 0.624
# 1    2  llama-zero-shot        0.530 0.624
# 2    3  llama-zero-shot        0.530 0.624
# 3    1   llama-few-shot        0.530 0.651
# 4    2   llama-few-shot        0.530 0.651
# 5    3   llama-few-shot        0.530 0.651
# 6    1        llama-sft        0.550 0.641
# 7    2        llama-sft        0.550 0.641
# 8    3        llama-sft        0.550 0.641

# %%
report_df[['jerx', 'exact_match', 'f1']].groupby('jerx').mean().loc[['llama-zero-shot', 'llama-few-shot', 'llama-sft']]
# Out:
#                  exact_match    f1
# jerx
# llama-zero-shot        0.530 0.624
# llama-few-shot         0.530 0.651
# llama-sft              0.550 0.641
